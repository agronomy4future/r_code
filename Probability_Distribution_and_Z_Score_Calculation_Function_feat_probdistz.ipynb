# %% [markdown]
# ## data upload

# %%
if(!require(readr)) install.packages("readr")
library(readr)
github="https://raw.githubusercontent.com/agronomy4future/raw_data_practice/main/grains.csv"
df = data.frame(read_csv(url(github), show_col_types=FALSE))
head(df,5)
# Out:
#   field    genotype block stage        treatment   shoot     grain_number
# 1 up_state cv_1     I     pre_anthesis treatment_1 main stem 513
# 2 up_state cv_1     I     pre_anthesis treatment_1 tillers   268
# 3 up_state cv_2     I     pre_anthesis treatment_1 main stem 616
# 4 up_state cv_2     I     pre_anthesis treatment_1 tillers    83
# 5 up_state cv_1     I     pre_anthesis control     main stem 516
#   grain_weight
# 1 49.26
# 2 44.68
# 3 45.19
# 4 44.34
# 5 48.25

# %% [markdown]
# # using stat_function()

# %% [markdown]
# ## to create PDF curve per genotype across all environments

# %%
if(!require(readr)) install.packages("ggplot2")
library(ggplot2)

# %%
ggplot(data=df, aes(x=grain_weight)) +

  stat_function(data=subset(df, genotype=="cv_1"), aes(color= "cv_1"), linewidth=1,
    fun=dnorm, args=list(mean=mean(subset(df, genotype=="cv_1")$grain_weight, na.rm=TRUE),
    sd=sd(subset(df, genotype=="cv_1")$grain_weight, na.rm=TRUE))) +

  stat_function(data=subset(df, genotype=="cv_2"), aes(color= "cv_2"), linewidth=1,
    fun=dnorm, args=list(mean=mean(subset(df, genotype=="cv_2")$grain_weight, na.rm=TRUE),
    sd=sd(subset(df, genotype=="cv_2")$grain_weight, na.rm=TRUE))) +

  stat_function(data=subset(df, genotype=="cv_3"), aes(color= "cv_3"), linewidth=1,
    fun=dnorm, args=list(mean=mean(subset(df, genotype=="cv_3")$grain_weight, na.rm=TRUE),
    sd=sd(subset(df, genotype=="cv_3")$grain_weight, na.rm=TRUE))) +

scale_color_manual(name= "Genotype", values = c("cv_1"="black", "cv_2"="red", "cv_3"="blue")) +
scale_x_continuous(breaks=seq(0,80,20), limits=c(0,80)) +
scale_y_continuous(breaks=seq(0,0.15,0.03), limits=c(0,0.15)) +
labs(x="Wheat grain weight (mg)", y="Frequency") +
theme_classic(base_size=15, base_family="serif") +
theme(legend.position=c(0.85, 0.85),
      legend.title=element_blank(),
      legend.key=element_rect(color="white", fill="white"),
      legend.text=element_text(family="serif", face="plain", size=15, color= "Black"),
      legend.background=element_rect(fill="white"),
      axis.line=element_line(linewidth=0.5, colour="black"))
# Out:
# plot without title

# %% [markdown]
# # to create PDF curve per genotype within each field

# %%
# upstate
ggplot(data=subset(df, field=="up_state"), aes(x=grain_weight)) +

 stat_function(data=subset(subset(df, field=="up_state"), genotype=="cv_1"),
  aes(color="cv_1"), linewidth=1, fun=dnorm,
  args=list(mean=mean(subset(subset(df, field=="up_state"), genotype=="cv_1")$grain_weight, na.rm=TRUE),
  sd=sd(subset(subset(df, field=="up_state"), genotype=="cv_1")$grain_weight, na.rm=TRUE))) +

 stat_function(data=subset(subset(df, field=="up_state"), genotype=="cv_2"),
  aes(color="cv_2"), linewidth=1, fun=dnorm,
  args=list(mean=mean(subset(subset(df, field=="up_state"), genotype=="cv_2")$grain_weight, na.rm=TRUE),
  sd=sd(subset(subset(df, field=="up_state"), genotype=="cv_2")$grain_weight, na.rm=TRUE))) +

 stat_function(data=subset(subset(df, field=="up_state"), genotype=="cv_3"),
  aes(color="cv_3"), linewidth=1, fun=dnorm,
  args=list(mean=mean(subset(subset(df, field=="up_state"), genotype=="cv_3")$grain_weight, na.rm=TRUE),
  sd=sd(subset(subset(df, field=="up_state"), genotype=="cv_3")$grain_weight, na.rm=TRUE))) +

 scale_color_manual(name= "Genotype", values = c("cv_1"="black", "cv_2"="red", "cv_3"="blue")) +
 scale_x_continuous(breaks=seq(0,80,20), limits=c(0,80)) +
 scale_y_continuous(breaks=seq(0,0.15,0.03), limits=c(0,0.15)) +
 labs(x="Wheat grain weight (mg)", y="Frequency") +
 theme_classic(base_size=15, base_family="serif") +
 theme(legend.position=c(0.85, 0.85),
       legend.title=element_blank(),
       legend.key=element_rect(color="white", fill="white"),
       legend.text=element_text(family="serif", face="plain", size=15, color= "Black"),
       legend.background=element_rect(fill="white"),
       axis.line=element_line(linewidth=0.5, colour="black"))
# Out:
# plot without title

# %%
# downstate
ggplot(data=subset(df, field=="down_state"), aes(x=grain_weight)) +

 stat_function(data=subset(subset(df, field=="down_state"), genotype=="cv_1"),
  aes(color="cv_1"), linewidth=1, fun=dnorm,
  args=list(mean=mean(subset(subset(df, field=="down_state"), genotype=="cv_1")$grain_weight, na.rm=TRUE),
  sd=sd(subset(subset(df, field=="down_state"), genotype=="cv_1")$grain_weight, na.rm=TRUE))) +

 stat_function(data=subset(subset(df, field=="down_state"), genotype=="cv_2"),
  aes(color="cv_2"), linewidth=1, fun=dnorm,
  args=list(mean=mean(subset(subset(df, field=="down_state"), genotype=="cv_2")$grain_weight, na.rm=TRUE),
  sd=sd(subset(subset(df, field=="down_state"), genotype=="cv_2")$grain_weight, na.rm=TRUE))) +

 stat_function(data=subset(subset(df, field=="down_state"), genotype=="cv_3"),
  aes(color="cv_3"), linewidth=1, fun=dnorm,
  args=list(mean=mean(subset(subset(df, field=="down_state"), genotype=="cv_3")$grain_weight, na.rm=TRUE),
  sd=sd(subset(subset(df, field=="down_state"), genotype=="cv_3")$grain_weight, na.rm=TRUE))) +

 scale_color_manual(name= "Genotype", values = c("cv_1"="black", "cv_2"="red", "cv_3"="blue")) +
 scale_x_continuous(breaks=seq(0,80,20), limits=c(0,80)) +
 scale_y_continuous(breaks=seq(0,0.15,0.03), limits=c(0,0.15)) +
 labs(x="Wheat grain weight (mg)", y="Frequency") +
 theme_classic(base_size=15, base_family="serif") +
 theme(legend.position=c(0.85, 0.85),
       legend.title=element_blank(),
       legend.key=element_rect(color="white", fill="white"),
       legend.text=element_text(family="serif", face="plain", size=15, color= "Black"),
       legend.background=element_rect(fill="white"),
       axis.line=element_line(linewidth=0.5, colour="black"))
# Out:
# plot without title

# %% [markdown]
# ################################################################################

# %% [markdown]
# # probdistz() package

# %%
if(!require(remotes)) install.packages("remotes")
if (!requireNamespace("probdistz", quietly = TRUE)) {
  remotes::install_github("agronomy4future/probdistz")
}
library(remotes)
library(probdistz)

# %% [markdown]
# ## to create PDF curve per genotype across all environments

# %%
dataA= probdistz(df, env_cols= c("genotype"), yield_cols= c("grain_weight"), smooth= TRUE)
set.seed(100)
dataA[sample(nrow(dataA),5),]
# Out:
#      grain_weight smooth_pdf   smooth_cdf   smooth_z    genotype
# 503  43.202023    7.468755e-02 5.119784e-01  0.03003003 cv_1
# 2035  8.003975    1.093519e-08 1.124988e-08 -5.59159159 cv_3
# 2967 74.349600    1.022410e-08 1.000000e+00  5.60360360 cv_3
# 470  41.085633    6.987111e-02 3.570459e-01 -0.36636637 cv_1
# 1990 71.736697    2.594938e-09 1.000000e+00  5.87987988 cv_2

# %%
ggplot(data=dataA, aes(x=grain_weight, y=smooth_pdf, color=genotype)) +
  geom_line ()+
  scale_color_manual(name= "Genotype", values= c("cv_1"="black", "cv_2"="red", "cv_3"="blue")) +
  scale_x_continuous(breaks=seq(0,80,20), limits=c(0,80)) +
  scale_y_continuous(breaks=seq(0,0.15,0.03), limits=c(0,0.15)) +
  labs(x="Wheat grain weight (mg)", y="Frequency") +
  theme_classic(base_size=15, base_family="serif") +
  theme(legend.position=c(0.85, 0.85),
        legend.title=element_blank(),
        legend.key=element_rect(color="white", fill="white"),
        legend.text=element_text(family="serif", face="plain", size=15, color= "Black"),
        legend.background=element_rect(fill="white"),
        axis.line=element_line(linewidth=0.5, colour="black"))
# Out:
# plot without title

# %% [markdown]
# # to create PDF curve per genotype within each field

# %%
dataA= probdistz(df, env_cols= c("field","genotype"), yield_cols= c("grain_weight"), smooth= TRUE)
set.seed(100)
dataA[sample(nrow(dataA),5),]
# Out:
#      grain_weight smooth_pdf   smooth_cdf   smooth_z    field      genotype
# 3786 53.69313     3.036760e-04 9.996976e-01  3.42942943 down_state cv_1
# 503  45.21273     6.573905e-02 5.119784e-01  0.03003003 up_state   cv_1
# 3430 38.00036     7.595374e-02 1.985402e-01 -0.84684685 down_state cv_1
# 3696 49.72585     6.898674e-03 9.905716e-01  2.34834835 down_state cv_1
# 4090 21.05160     4.985506e-07 4.091933e-07 -4.93093093 down_state cv_3

# %%
# upstate
ggplot(data=subset(dataA, field=="up_state"), aes(x=grain_weight, y=smooth_pdf, color=genotype)) +
  geom_line ()+
  scale_color_manual(name= "Genotype", values= c("cv_1"="black", "cv_2"="red", "cv_3"="blue")) +
  scale_x_continuous(breaks=seq(0,80,20), limits=c(0,80)) +
  scale_y_continuous(breaks=seq(0,0.15,0.03), limits=c(0,0.15)) +
  labs(x="Wheat grain weight (mg)", y="Frequency") +
  theme_classic(base_size=15, base_family="serif") +
  theme(legend.position=c(0.85, 0.85),
        legend.title=element_blank(),
        legend.key=element_rect(color="white", fill="white"),
        legend.text=element_text(family="serif", face="plain", size=15, color= "Black"),
        legend.background=element_rect(fill="white"),
        axis.line=element_line(linewidth=0.5, colour="black"))
# Out:
# Warning message:
# “Removed 100 rows containing missing values or values outside the scale range
# (`geom_line()`).”
# plot without title

# %%
# downstate
ggplot(data=subset(dataA, field=="down_state"), aes(x=grain_weight, y=smooth_pdf, color=genotype)) +
  geom_line ()+
  scale_color_manual(name= "Genotype", values= c("cv_1"="black", "cv_2"="red", "cv_3"="blue")) +
  scale_x_continuous(breaks=seq(0,80,20), limits=c(0,80)) +
  scale_y_continuous(breaks=seq(0,0.15,0.03), limits=c(0,0.15)) +
  labs(x="Wheat grain weight (mg)", y="Frequency") +
  theme_classic(base_size=15, base_family="serif") +
  theme(legend.position=c(0.85, 0.85),
        legend.title=element_blank(),
        legend.key=element_rect(color="white", fill="white"),
        legend.text=element_text(family="serif", face="plain", size=15, color= "Black"),
        legend.background=element_rect(fill="white"),
        axis.line=element_line(linewidth=0.5, colour="black"))
# Out:
# plot without title

# %% [markdown]
# # CDF curve

# %% [markdown]
# ## using stat_function()

# %%
ggplot() +

  stat_function(fun= pnorm,
      args= list(mean= mean(subset(subset(df, field=="up_state"), genotype== "cv_1")$grain_weight, na.rm= TRUE),
      sd= sd(subset(subset(df, field=="up_state"), genotype== "cv_1")$grain_weight, na.rm= TRUE)), aes(color= "cv_1"), linewidth= 1) +

  stat_function(fun= pnorm,
      args= list(mean= mean(subset(subset(df, field=="up_state"), genotype== "cv_2")$grain_weight, na.rm= TRUE),
      sd= sd(subset(subset(df, field=="up_state"), genotype== "cv_2")$grain_weight, na.rm= TRUE)), aes(color= "cv_2"), linewidth= 1) +

  stat_function(fun= pnorm,
      args= list(mean= mean(subset(subset(df, field=="up_state"), genotype== "cv_3")$grain_weight, na.rm= TRUE),
      sd= sd(subset(subset(df, field=="up_state"), genotype== "cv_3")$grain_weight, na.rm= TRUE)), aes(color= "cv_3"), linewidth= 1) +

  scale_color_manual(name= "Genotype", values= c("cv_1"= "black", "cv_2"= "red", "cv_3"= "blue")) +
  scale_x_continuous(breaks= seq(0, 80, 20), limits= c(0, 80)) +
  scale_y_continuous(breaks= seq(0, 1, 0.2), limits= c(0, 1)) +
  labs(x= "Wheat grain weight (mg)", y= "Frequency") +
  theme_classic(base_size= 15, base_family= "serif") +
  theme(legend.position= c(0.85, 0.85),
        legend.title= element_blank(),
        legend.key= element_rect(color= "white", fill= "white"),
        legend.text= element_text(family= "serif", face= "plain", size= 15, color= "Black"),
        legend.background= element_rect(fill = "white"),
        axis.line= element_line(linewidth= 0.5, colour= "black"))
# Out:
# plot without title

# %% [markdown]
# # using probdistz()

# %%
dataA= probdistz(df, env_cols= c("field","genotype"), yield_cols= c("grain_weight"), smooth= TRUE)

# %%
ggplot(data=subset(dataA, field=="up_state"), aes(x=grain_weight, y=smooth_cdf, color=genotype)) +
  geom_line ()+
  scale_color_manual(name= "Genotype", values = c("cv_1"="black", "cv_2"="red", "cv_3"="blue")) +
  scale_x_continuous(breaks=seq(0,80,20), limits=c(0,80)) +
  scale_y_continuous(breaks=seq(0,1,0.2), limits=c(0,1)) +
  labs(x="Wheat grain weight (mg)", y="Frequency") +
  theme_classic(base_size=15, base_family="serif") +
  theme(legend.position=c(0.85, 0.85),
        legend.title=element_blank(),
        legend.key=element_rect(color="white", fill="white"),
        legend.text=element_text(family="serif", face="plain", size=15, color= "Black"),
        legend.background=element_rect(fill="white"),
        axis.line=element_line(linewidth=0.5, colour="black"))
# Out:
# Warning message:
# “Removed 100 rows containing missing values or values outside the scale range
# (`geom_line()`).”
# plot without title

# %% [markdown]
# # Z-distribution

# %%
dataA= probdistz(df, env_cols= c("field","genotype"), yield_cols= c("grain_weight"), smooth= TRUE)

# %%
ggplot(data=subset(dataA, field=="up_state"), aes(x=smooth_z, y=smooth_pdf, color=genotype)) +
  geom_line ()+
  scale_color_manual(name= "Genotype", values= c("cv_1"="black", "cv_2"="red", "cv_3"="blue")) +
  scale_x_continuous(breaks=seq(-4,4,1), limits=c(-4,4)) +
  scale_y_continuous(breaks=seq(0,0.2,0.05), limits=c(0,0.2)) +
  labs(x="Z-score", y="Frequency") +
  theme_classic(base_size=15, base_family="serif") +
  theme(legend.position=c(0.85, 0.85),
        legend.title=element_blank(),
        legend.key=element_rect(color="white", fill="white"),
        legend.text=element_text(family="serif", face="plain", size=15, color= "Black"),
        legend.background=element_rect(fill="white"),
        axis.line=element_line(linewidth=0.5, colour="black"))
# Out:
# Warning message:
# “Removed 1002 rows containing missing values or values outside the scale range
# (`geom_line()`).”
# plot without title

# %% [markdown]
# # When selecting smooth= FALSE (This graph is the same as using Excel)

# %%
dataA= probdistz(df, env_cols= c("field","genotype"), yield_cols= c("grain_weight"), smooth= FALSE)

# %%
ggplot(data=subset(dataA, field=="up_state"), aes(x=grain_weight, y=pdf_grain_weight, color=genotype)) +
  geom_point ()+
  scale_color_manual(name= "Genotype", values= c("cv_1"="black", "cv_2"="red", "cv_3"="blue")) +
  scale_x_continuous(breaks=seq(0,80,20), limits=c(0,80)) +
  scale_y_continuous(breaks=seq(0,0.15,0.03), limits=c(0,0.15)) +
  labs(x="Wheat grain weight (mg)", y="Frequency") +
  theme_classic(base_size=15, base_family="serif") +
  theme(legend.position=c(0.85, 0.85),
        legend.title=element_blank(),
        legend.key=element_rect(color="white", fill="white"),
        legend.text=element_text(family="serif", face="plain", size=15, color= "Black"),
        legend.background=element_rect(fill="white"),
        axis.line=element_line(linewidth=0.5, colour="black"))
# Out:
# plot without title
