# %%
x=c(10,20,30,40,50)
y=c(5,8,12,18,19)
dataA=data.frame(x,y)
dataA

# %%
library(ggplot2)
ggplot(data=dataA, aes(x=x, y=y)) +
  geom_smooth(method= lm, level=0.95, se=FALSE, linetype=1, color="Red", linewidth=1, formula= y ~ x) +
  geom_point(col="Blue", size=3)
# Out:
# plot without title

# %%
ggplot(data=dataA, aes(x=x, y=y)) +
  geom_smooth(method= lm, level=0.95, se=FALSE, linetype=1, color="Red", linewidth=1, formula= y ~ x) +
  geom_point(col="Blue", size=3) +
  geom_abline (slope=1, linetype= "dashed", color="Black", size=2) +
  scale_x_continuous(breaks= seq(0,50,10), limits= c(0,50)) +
  scale_y_continuous(breaks= seq(0,50,10), limits= c(0,50))
# Out:
# plot without title

# %%
ggplot(data=dataA, aes(x=x, y=y)) +
  geom_smooth(method= lm, level=0.95, se=FALSE, linetype=1, color="Red", linewidth=1, formula= y ~ x) +
  geom_point(col="Blue", size=3) +
  geom_abline (slope=1, linetype= "dashed", color="Black", size=2) +
  geom_vline(xintercept= 50, linetype= "dashed", color="Green") +
  geom_hline(yintercept=50, linetype="solid", color= "Blue") +
  scale_x_continuous(breaks= seq(0,50,10), limits= c(0,50)) +
  scale_y_continuous(breaks= seq(0,50,10), limits= c(0,50))
# Out:
# plot without title
