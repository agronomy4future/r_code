# %%
library (ggplot2)
library (dplyr)
library(tidyr)

# %%
Nitrogen= c(rep("N0", 5), rep("N1", 5))
Cultivar_1= c(50,49,48,47,46,60,62,63,64,62)
Cultivar_2= c(55,57,56,55,54,65,66,67,64,63)
Cultivar_3= c(60,62,63,65,59,60,59,57,56,58)
dataA= data.frame(Nitrogen, Cultivar_1, Cultivar_2, Cultivar_3)
dataA
# Out:
#    Nitrogen Cultivar_1 Cultivar_2 Cultivar_3
# 1  N0       50         55         60
# 2  N0       49         57         62
# 3  N0       48         56         63
# 4  N0       47         55         65
# 5  N0       46         54         59
# 6  N1       60         65         60
# 7  N1       62         66         59
# 8  N1       63         67         57
# 9  N1       64         64         56
# 10 N1       62         63         58

# %%
df= data.frame(
               dataA %>%
               pivot_longer(
               cols=c(Cultivar_1, Cultivar_2, Cultivar_3),
               names_to="Genotype", values_to="Yield")
               )
df
# Out:
#    Nitrogen Genotype   Yield
# 1  N0       Cultivar_1 50
# 2  N0       Cultivar_2 55
# 3  N0       Cultivar_3 60
# 4  N0       Cultivar_1 49
# 5  N0       Cultivar_2 57
# 6  N0       Cultivar_3 62
# 7  N0       Cultivar_1 48
# 8  N0       Cultivar_2 56
# 9  N0       Cultivar_3 63
# 10 N0       Cultivar_1 47
# 11 N0       Cultivar_2 55
# 12 N0       Cultivar_3 65
# 13 N0       Cultivar_1 46
# 14 N0       Cultivar_2 54
# 15 N0       Cultivar_3 59
# 16 N1       Cultivar_1 60
# 17 N1       Cultivar_2 65
# 18 N1       Cultivar_3 60
# 19 N1       Cultivar_1 62
# 20 N1       Cultivar_2 66
# 21 N1       Cultivar_3 59
# 22 N1       Cultivar_1 63
# 23 N1       Cultivar_2 67
# 24 N1       Cultivar_3 57
# 25 N1       Cultivar_1 64
# 26 N1       Cultivar_2 64
# 27 N1       Cultivar_3 56
# 28 N1       Cultivar_1 62
# 29 N1       Cultivar_2 63
# 30 N1       Cultivar_3 58

# %%
dataB= data.frame(df %>%
  group_by(Genotype, Nitrogen) %>%
  dplyr::summarize(across(c(Yield),
                          .fns = list(Mean = mean,
                                      SD = sd,
                                      n = length,
                                      se = ~ sd(.)/sqrt(length(.))))))
dataB
# Out:
# `summarise()` has grouped output by 'Genotype'. You can override using the
# `.groups` argument.
#   Genotype   Nitrogen Yield_Mean Yield_SD Yield_n Yield_se
# 1 Cultivar_1 N0       48.0       1.581139 5       0.7071068
# 2 Cultivar_1 N1       62.2       1.483240 5       0.6633250
# 3 Cultivar_2 N0       55.4       1.140175 5       0.5099020
# 4 Cultivar_2 N1       65.0       1.581139 5       0.7071068
# 5 Cultivar_3 N0       61.8       2.387467 5       1.0677078
# 6 Cultivar_3 N1       58.0       1.581139 5       0.7071068

# %%
ggplot (data=dataB, aes(x=Genotype, y=Yield_Mean, fill=Nitrogen)) +
  geom_bar(stat="identity",position="dodge") +
  geom_errorbar(aes(ymin= Yield_Mean-Yield_se, ymax= Yield_Mean+Yield_se),
                position=position_dodge(0.9), width=0.2) +
  scale_fill_manual(values= c("Gray","Dark green")) +
  scale_y_continuous(breaks= seq(0, 100, 20), limits= c(0, 100))+
  facet_wrap(~Nitrogen) +
  labs(x="Cultivar", y="Yield") +
  theme_classic(base_size=18, base_family="serif")+
  theme(legend.position='bottom',
        legend.title=element_blank(),
        legend.key=element_rect(color="white", fill="white"),
        legend.text=element_text(family="serif", face="plain",
                                 size=15, color= "Black"),
        axis.line=element_line(linewidth=0.5, colour="black"))
# Out:
# plot without title

# %%
ggplot (data=dataB, aes(x=Genotype, y=Yield_Mean, fill=Nitrogen)) +
  geom_bar(stat="identity",position="dodge") +
  geom_errorbar(aes(ymin= Yield_Mean-Yield_se, ymax= Yield_Mean+Yield_se),
                position=position_dodge(0.9), width=0.2) +
  scale_fill_manual(values= c("Gray","Dark green")) +
  scale_y_continuous(breaks= seq(0, 100, 20), limits= c(0, 100))+
  facet_wrap(~Nitrogen) +
  labs(x="Cultivar", y="Yield") +
  theme_classic(base_size=18, base_family="serif")+
  theme(legend.position='bottom',
        legend.title=element_blank(),
        legend.key=element_rect(color="white", fill="white"),
        legend.text=element_text(family="serif", face="plain",
                                 size=15, color= "Black"),
        axis.line=element_line(linewidth=0.5, colour="black"),
        strip.background=element_rect(color="white",
                                      linewidth=0.5, linetype="solid"))
# Out:
# plot without title

# %%
ggplot (data=dataB, aes(x=Genotype, y=Yield_Mean, fill=Nitrogen)) +
  geom_bar(stat="identity",position="dodge") +
  geom_errorbar(aes(ymin= Yield_Mean-Yield_se, ymax= Yield_Mean+Yield_se),
                position=position_dodge(0.9), width=0.2) +
  scale_fill_manual(values= c("Gray","Dark green")) +
  scale_y_continuous(breaks= seq(0, 100, 20), limits= c(0, 100))+
  facet_wrap(~Nitrogen) +
  annotate("segment", x=1, xend=3, y=Inf, yend=Inf, color="black", lwd=1)+
  labs(x="Cultivar", y="Yield") +
  theme_classic(base_size=18, base_family="serif")+
  theme(legend.position='bottom',
        legend.title=element_blank(),
        legend.key=element_rect(color="white", fill="white"),
        legend.text=element_text(family="serif", face="plain",
                                 size=15, color= "Black"),
        axis.line=element_line(linewidth=0.5, colour="black"),
        strip.background=element_rect(color="white",
                                      linewidth=0.5, linetype="solid"))
# Out:
# plot without title
